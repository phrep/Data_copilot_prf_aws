# %%
from langchain_qdrant import QdrantVectorStore
from langchain_community.embeddings import HuggingFaceEmbeddings

db = QdrantVectorStore.from_existing_collection(
    collection_name="prf_acidentes_schema",
    url="http://13.222.175.92:6333",
    embedding=HuggingFaceEmbeddings(
        model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
    )
)

resultado = db.similarity_search("quantidade de acidentes por estado")

for doc in resultado:
    print(doc.page_content)


if __name__ == "__main__":
    from qdrant_client import QdrantClient

    client = QdrantClient(url="http://13.222.175.92:6333")

    points = client.scroll(
        collection_name="prf_acidentes_schema",
        limit=15
    )

    print(points)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 8302.17it/s]
# BertModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Exemplo: quantidade de acidentes por estado
#
# SELECT uf, COUNT(*) as total_acidentes
# FROM tabela_prf_all_acidentes_db
# GROUP BY uf
#
#
# Exemplo: acidentes por ano
#
# SELECT ano, COUNT(*) as total
# FROM tabela_prf_all_acidentes_db
# GROUP BY ano
#
#
# Para calcular número de acidentes:
#
# Use:
# SELECT COUNT(*) FROM tabela_prf_all_acidentes_db
#
# Para agrupamentos:
# SELECT coluna, COUNT(*)
# FROM tabela_prf_all_acidentes_db
# GROUP BY coluna
#
#
# Tabela: tabela_prf_all_acidentes_db
#
# Descrição:
# Tabela contendo registros de acidentes em rodovias federais do Brasil.
#
# Use esta tabela para análises de:
# - quantidade de acidentes
# - análises por estado (uf)
# - análises temporais (ano, mês, dia)
# - causas e tipos de acidentes
#
# ([Record(id='01a60695-46c2-45a8-9331-de9822a2aa62', payload={'page_content': '\nExemplo: total de mortos por estado\n\nSELECT uf, SUM(CAST(mortos AS INTEGER)) as total_mortos\nFROM tabela_prf_all_acidentes_db\nGROUP BY uf\n', 'metadata': {'type': 'sql_example'}}, vector=None, shard_key=None, order_value=None), Record(id='1c9a6875-8eb9-469b-badd-60d6bc5c2d02', payload={'page_content': '\nColuna: id\nDescrição: Identificador único do acidente\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: id\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'id', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='2c31c25d-8db9-40cc-94b9-78d6efabf294', payload={'page_content': '\nColuna: marca\nDescrição: Marca do veículo\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: marca\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'marca', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='2de276cc-01d7-4128-b29b-f832c0ad36f4', payload={'page_content': '\nColuna: classificacao_acidente\nDescrição: Gravidade do acidente\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: classificacao_acidente\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'classificacao_acidente', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='2f80910c-015e-42e3-9a91-b926fe1607e7', payload={'page_content': '\nColuna: uf\nDescrição: Estado (UF)\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: uf\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'uf', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='3157e603-d03f-4121-a237-b9aee948cf1d', payload={'page_content': '\nColuna: feridos_leves\nDescrição: Feridos leves (string numérica)\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: feridos_leves\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'feridos_leves', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='3f33f21e-3f70-4f77-b760-556503171328', payload={'page_content': '\nPara calcular número de acidentes:\n\nUse:\nSELECT COUNT(*) FROM tabela_prf_all_acidentes_db\n\nPara agrupamentos:\nSELECT coluna, COUNT(*) \nFROM tabela_prf_all_acidentes_db\nGROUP BY coluna\n', 'metadata': {'type': 'metric'}}, vector=None, shard_key=None, order_value=None), Record(id='430e384c-7a96-418f-beb8-23c235455882', payload={'page_content': '\nColuna: br\nDescrição: Rodovia BR onde ocorreu o acidente\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: br\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'br', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='5627138c-01cc-49ad-9a33-bcb048a3260d', payload={'page_content': '\nColuna: ano\nDescrição: Ano (partição)\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: ano\n- Esta coluna pertence à tabela tabela_prf_all_acidentes_db\n', 'metadata': {'type': 'column', 'column_name': 'ano', 'table': 'tabela_prf_all_acidentes_db'}}, vector=None, shard_key=None, order_value=None), Record(id='57a5c205-31f9-42eb-a599-ee71636624f8', payload={'page_content': '\nColuna: idade\nDescrição: Idade da pessoa\nTabela: tabela_prf_all_acidentes_db\n\nInstruções:\n- Use exatamente o nome da coluna: idade\n- Esta coluna pertence à tabela tabela_prf_all_acidente ...
